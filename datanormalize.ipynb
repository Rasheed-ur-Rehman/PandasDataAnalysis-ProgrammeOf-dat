# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'C:\Users\R4PC3\Desktop\HWMgsC.csv')

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
 data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data.plot(kind='bar', stacked=True);

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.plot(kind='barh', stacked=True);

# %%
data.plot(kind='hist', stacked=True, bins=20)

# %%
data['math score'].plot(kind='hist', orientation='horizontal', cumulative=True)

# %%
data['math score'].diff().hist()

# %%
data.plot(kind='box')

# %%
data.plot(kind='area');

# %%
data.plot(kind='area', stacked=False);

# %%
data.plot(kind='scatter', x='math score', y='reading score');

# %%
 ax = data.plot(kind='scatter', x='math score', y='reading score',
                color='DarkBlue', label='Group 1');
    
 data.plot(kind='scatter', x='math score', y='reading score',
            color='DarkGreen', label='Group 2', ax=ax);
